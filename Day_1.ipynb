# %%
#Practice all Operations of 
List , 
Touple, 
Set,
Dictionary,
String

# %% [markdown]
# List

# %%
lst=[1,2,3,4,5,7,8,22,55,44]

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 7, 8, 22, 55, 44]

# %%
lst_1=['alice',2,8,'bob']

# %%
lst_1
# Out:
# ['alice', 2, 8, 'bob']

# %%
lst_2=[1,"john",40.25,"wick",8,10.2]

# %%
lst_2
# Out:
# [1, 'john', 40.25, 'wick', 8, 10.2]

# %%
print(type(lst))
print(type(lst_1))
type(lst_2)
# Out:
# <class 'list'>
# <class 'list'>
# list

# %%
lst.append(50)

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 7, 8, 22, 55, 44, 50]

# %%
lst_1.clear()

# %%
lst_1
# Out:
# []

# %%
copy_of_lst_2=lst_2.copy()

# %%
copy_of_lst_2
# Out:
# [1, 'john', 40.25, 'wick', 8, 10.2]

# %%
lst_1=lst_2.copy()

# %%
lst_1
# Out:
# [1, 'john', 40.25, 'wick', 8, 10.2]

# %%
print(lst)
print(lst_1)
lst_2
# Out:
# [1, 2, 3, 4, 5, 7, 8, 22, 55, 44, 50]
# [1, 'john', 40.25, 'wick', 8, 10.2]
# [1, 'john', 40.25, 'wick', 8, 10.2]

# %%
lst_2.count(4)
# Out:
# 0

# %%
lst_1.count("john")
# Out:
# 1

# %%
lst_2.count(8)
# Out:
# 1

# %%
lst.extend(lst_2)

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 7, 8, 22, 55, 44, 50, 1, 'john', 40.25, 'wick', 8, 10.2]

# %%
lst.index(8)
# Out:
# 6

# %%
lst.insert(5,8)

# %%
lst.pop()
# Out:
# 10.2

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 8, 7, 8, 22, 55, 44, 50, 1, 'john', 40.25, 'wick', 8]

# %%
lst.pop(2)
# Out:
# 3

# %%
lst
# Out:
# [1, 2, 4, 5, 8, 7, 8, 22, 55, 44, 50, 1, 'john', 40.25, 'wick', 8]

# %%
lst.remove(8)

# %%
lst
# Out:
# [1, 2, 4, 5, 7, 8, 22, 55, 44, 50, 1, 'john', 40.25, 'wick', 8]

# %%
lst.reverse()

# %%
lst
# Out:
# [8, 'wick', 40.25, 'john', 1, 50, 44, 55, 22, 8, 7, 5, 4, 2, 1]

# %%
lst.remove("john")

# %%
lst
# Out:
# [8, 40.25, 1, 50, 44, 55, 22, 8, 7, 5, 4, 2, 1]

# %%
lst.sort()        # to sort the list must have all are numbers

# %%
lst
# Out:
# [1, 1, 2, 4, 5, 7, 8, 8, 22, 40.25, 44, 50, 55]

# %%
ls=lst.__add__(lst_2)

# %%
lst
# Out:
# [1, 1, 2, 4, 5, 7, 8, 8, 22, 40.25, 44, 50, 55]

# %%
ls
# Out:
# [1,
#  1,
#  2,
#  4,
#  5,
#  7,
#  8,
#  8,
#  22,
#  40.25,
#  44,
#  50,
#  55,
#  1,
#  'john',
#  40.25,
#  'wick',
#  8,
#  10.2]

# %%
ls.remove('wick')

# %%
ls
# Out:
# [1, 1, 2, 4, 5, 7, 8, 8, 22, 40.25, 44, 50, 55, 1, 40.25, 8, 10.2]

# %%
lst
# Out:
# [1, 1, 2, 4, 5, 7, 8, 8, 22, 40.25, 44, 50, 55]

# %%
lst.__len__()  #length of list
# Out:
# 13

# %%
len(lst)
# Out:
# 13

# %%
lst.__contains__(8)        #if values is exist in list then print True else False
# Out:
# True

# %%
lst.__sizeof__()    #size of the list object in bytes
# Out:
# 232

# %% [markdown]
# Tuple

# %%
tp=(1,5,5,26,24,825,22,8,8,12,0,2,0,58,55)       #immutable

# %%
tp
# Out:
# (1, 5, 5, 26, 24, 825, 22, 8, 8, 12, 0, 2, 0, 58, 55)

# %%
tp.index(8)
# Out:
# 7

# %%
tp.index(8)
# Out:
# 7

# %%
tp.count(8)
# Out:
# 2

# %%
tp.count(0)
# Out:
# 2

# %%
len(tp)
# Out:
# 15

# %% [markdown]
# Set

# %%
st={"john",'alice',55,22,14,0,10,1,2,86,56,2,0,8,5,8,20,10}

# %%
st    # remove duplicate values from set       # this is unordered collection
# Out:
# {0, 1, 10, 14, 2, 20, 22, 5, 55, 56, 8, 86, 'alice', 'john'}

# %%
st.add(88)

# %%
st
# Out:
# {0, 1, 10, 14, 2, 20, 22, 5, 55, 56, 8, 86, 88, 'alice', 'john'}

# %%
st.add(86)

# %%
st
# Out:
# {0, 1, 10, 14, 2, 20, 22, 5, 55, 56, 8, 86, 88, 'alice', 'john'}

# %%
s=st.copy()

# %%
s
# Out:
# {0, 1, 10, 14, 2, 20, 22, 5, 55, 56, 8, 86, 88, 'alice', 'john'}

# %%
st.difference(s)
# Out:
# set()

# %%
s.remove('alice')

# %%
s.remove('john')

# %%
s
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 55, 56, 86, 88}

# %%
st
# Out:
# {0, 1, 10, 14, 2, 20, 22, 5, 55, 56, 8, 86, 88, 'alice', 'john'}

# %%
st.difference(s)
# Out:
# {'alice', 'john'}

# %%
st.difference_update(s)   # st will update only with  not common values

# %%
st
# Out:
# {'alice', 'john'}

# %%
s
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 55, 56, 86, 88}

# %%
st
# Out:
# {'alice', 'john'}

# %%
st=s.copy()

# %%
st
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 55, 56, 86, 88}

# %%
st.add(55)

# %%
st
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 55, 56, 86, 88}

# %%
st.discard(55)        #like remove delete that element

# %%
st
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 56, 86, 88}

# %%
st.intersection(s)        # common elements in both collections
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 56, 86, 88}

# %%
st.intersection(lst)
# Out:
# {1, 2, 5, 8, 22}

# %%
st.issubset(s)   # st is sub set of s in True/False
# Out:
# True

# %%
s
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 55, 56, 86, 88}

# %%
st
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 56, 86, 88}

# %%
st.isdisjoint(s)        # if two sets have no any common element then true else false
# Out:
# False

# %%
s1={1020,20003,102}
s1
# Out:
# {102, 1020, 20003}

# %%
st.isdisjoint(s1)      #Return True if two sets have a null intersection
# Out:
# True

# %%
st.discard(10)    #Remove an element from a set if it is a member.Unlike set.
                    #remove(), the discard() method does not raise an exception when an element is missing from the set.

# %%
st.discard(10)

# %%
st.remove(10)         #Remove an element from a set; it must be a member.If the element is not a member, raise a KeyError.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 st.remove(10)
#
# KeyError: 10

# %%
st.issuperset(s)        #Report whether this set contains another set.
# Out:
# False

# %%
s.issuperset(st)
# Out:
# True

# %%
st.pop()
# Out:
# 0

# %%
st
# Out:
# {1, 2, 5, 8, 14, 20, 22, 56, 86, 88}

# %%
s
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 55, 56, 86, 88}

# %%
s2=st.symmetric_difference(s)      #Return a new set with elements in either the set or other but not both (like  uncommon elements in boyh sets)

# %%
s2
# Out:
# {0, 10, 55}

# %%
s.symmetric_difference(st)
# Out:
# {0, 10, 55}

# %%
st.union(s)
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 55, 56, 86, 88}

# %%
st.update(s)       #Update the set, adding elements from all others.

# %%
st
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 55, 56, 86, 88}

# %%
s
# Out:
# {0, 1, 2, 5, 8, 10, 14, 20, 22, 55, 56, 86, 88}

# %% [markdown]
# Dictionary

# %%
dict={1:"omkar",2:"prathamesh",3:"atharav","course":"big data"}       # key -value pair

# %%
dict
# Out:
# {1: 'omkar', 2: 'prathamesh', 3: 'atharav', 'course': 'big data'}

# %%
dict.get(2)     #Return the value for key if key is in the dictionary, else default.
# Out:
# 'prathamesh'

# %%
dict.get(5,"Key Not found")
# Out:
# 'Key Not found'

# %%
dict.items()     #Return a set-like object providing a view on the dict's items.
# Out:
# dict_items([(1, 'omkar'), (2, 'prathamesh'), (3, 'atharav'), ('course', 'big data')])

# %%
dict.keys()
# Out:
# dict_keys([1, 2, 3, 'course'])

# %%
dict.values()
# Out:
# dict_values(['omkar', 'prathamesh', 'atharav', 'big data'])

# %%
dict.pop('course')         #D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
                    #If the key is not found, return the default if given; otherwise, raise a KeyError.
# Out:
# 'big data'

# %%
dict.popitem()        # result returned into tuple format
# Out:
# ('error', None)

# %%
dict
# Out:
# {1: 'omkar', 2: 'prathamesh', 3: 'atharav'}

# %%
dict.setdefault('error')

# %%
dict
# Out:
# {1: 'omkar', 2: 'prathamesh', 3: 'atharav', 'error': None}

# %%
dict
# Out:
# {1: 'omkar', 2: 'prathamesh', 3: 'atharav', 'error': None}

# %%
dict.__len__()
# Out:
# 4

# %%
my_dict = {"name": "Alice", "age": 30}
new_data = {"age": 31, "city": "New York"}

# %%
my_dict
# Out:
# {'name': 'Alice', 'age': 30}

# %%
my_dict.update(new_data)      #All key-value pairs from the other dictionary are added to the dict. 
                                #If a key already exists in dict, its value is updated with the value from other.

# %%
my_dict
# Out:
# {'name': 'Alice', 'age': 31, 'city': 'New York'}

# %%
new_data
# Out:
# {'age': 31, 'city': 'New York'}

# %% [markdown]
# String

# %%
a="python"

# %%
a.capitalize()
# Out:
# 'Python'

# %%
a.casefold()        #Return a version of the string suitable for caseless comparisons.
# Out:
# 'python'

# %%
a.encode()     #Encode the string using the codec registered for encoding.
                #encoding -the encoding in which to encode the string.
# Out:
# b'python'

# %%
a.count('a')
# Out:
# 0

# %%
a.endswith('n')
# Out:
# True

# %%
a.endswith("k")
# Out:
# False

# %%
a.expandtabs()
# Out:
# 'python'

# %%
a.format_map({})
# Out:
# 'python'

# %%
a.find("t")
# Out:
# 2

# %%
a.index("t")
# Out:
# 2

# %%
a.isalnum()
# Out:
# True

# %%
a.isalpha()
# Out:
# True

# %%
a.isdecimal()
# Out:
# False

# %%
a.isascii()
# Out:
# True

# %%
a.isidentifier()
# Out:
# True

# %%
a.isdigit()
# Out:
# False

# %%
a.islower()
# Out:
# True

# %%
a.istitle()
# Out:
# False

# %%
a.isprintable()
# Out:
# True

# %%
a.isupper()
# Out:
# False

# %%
a.join("code")
# Out:
# 'cpythonopythondpythone'

# %%
a.isspace()
# Out:
# False

# %%
a.lower()
# Out:
# 'python'

# %%
a.rpartition("t")
# Out:
# ('py', 't', 'hon')

# %%
a.split()
# Out:
# ['python']

# %%
a.split("y")
# Out:
# ['p', 'thon']

# %%
a.upper()
# Out:
# 'PYTHON'

# %%
a.rstrip("t")
# Out:
# 'python'

# %%
a.center(4)
# Out:
# 'python'

# %%
b="I am coding python"

# %%
b
# Out:
# 'I am coding python'

# %%
b.center(5)
# Out:
# 'I am coding python'

# %%
b.center(45,"*")
# Out:
# '**************I am coding python*************'

# %%
a.center(45)
# Out:
# '                    python                   '
