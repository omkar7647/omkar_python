# %% [markdown]
# # Basic Dictionay Operations

# %% [markdown]
# 1. Create a dictionary with 3 key-value pairs (name, age, city).

# %%
dict={"name":"Naredra","age":75,"city":"Gujarat"}
dict
# Out:
# {'name': 'Naredra', 'age': 75, 'city': 'Gujarat'}

# %% [markdown]
# 2. Create a dictionary and print the value of a specific key.

# %%
dict={"name":"Naredra","age":75,"city":"Gujarat"}
dict.get("name")
# Out:
# 'Naredra'

# %%
dict={"name":"Naredra","age":75,"city":"Gujarat"}
dict["name"]
# Out:
# 'Naredra'

# %% [markdown]
# 3. Make a dictionary and add a new key-value pair to it.

# %%
dict={"name":"Naredra","age":75,"city":"Gujarat"}
dict.update({"position":"PM"})
dict
# Out:
# {'name': 'Naredra', 'age': 75, 'city': 'Gujarat', 'position': 'PM'}

# %% [markdown]
# 4. Create a dictionary and change the value of an existing key.

# %%
dict={"name":"Naredra","age":75,"city":"Gujarat"}
dict.update({"age":76})
dict
# Out:
# {'name': 'Naredra', 'age': 76, 'city': 'Gujarat'}

# %% [markdown]
# 5. Create a dictionary and remove one key using pop().

# %%
dict={"name":"Naredra","age":75,"city":"Gujarat"}
dict.pop("city")
dict
# Out:
# {'name': 'Naredra', 'age': 75}

# %% [markdown]
# 6. Create a dictionary and remove the last inserted item using popitem().

# %%
dict={1:"omkar",2:"prathamesh",3:"atharva",4:"om",5:"pratik"}
dict.popitem()
# Out:
# (5, 'pratik')

# %% [markdown]
# 7. Create a dictionary and print all the keys.

# %%
dict={1:"omkar",2:"prathamesh",3:"atharva",4:"om",5:"pratik"}
dict.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %% [markdown]
# 8. Create a dictionary and print all the values.

# %%
dict={1:"omkar",2:"prathamesh",3:"atharva",4:"om",5:"pratik"}
dict.values()
# Out:
# dict_values(['omkar', 'prathamesh', 'atharva', 'om', 'pratik'])

# %% [markdown]
# 9. Create a dictionary and print all the key-value items.

# %%
dict={1:"omkar",2:"prathamesh",3:"atharva",4:"om",5:"pratik"}
dict.items()
# Out:
# dict_items([(1, 'omkar'), (2, 'prathamesh'), (3, 'atharva'), (4, 'om'), (5, 'pratik')])

# %% [markdown]
# 10. Make a dictionary and check the number of items using len().

# %%
dict={1:"omkar",2:"prathamesh",3:"atharva",4:"om",5:"pratik"}
len(dict)
# Out:
# 5

# %% [markdown]
# 11. Create a dictionary and check if a certain key exists (using "key" in dict).

# %%
abc={"name":"xyz","city":"pune","gender":"M","status":"Active"}
abc.keys()
# Out:
# dict_keys(['name', 'city', 'gender', 'status'])

# %% [markdown]
# 12. Create an empty dictionary and add two key-value pairs one by one.

# %%
emp={}
emp.update({1:"alice"})
emp.update({2:'bob'})
emp
# Out:
# {1: 'alice', 2: 'bob'}

# %% [markdown]
# 13. Create a dictionary and update one key’s value using update().

# %%
emp.update({2:"john"})
emp
# Out:
# {1: 'alice', 2: 'john'}

# %% [markdown]
# 14. Create two dictionaries and combine them using update().

# %%
com={1:"TCS",2:"Google",3:"TATA"}
city={1101:"pune",102:"mumbai"}
com.update(city)
com
# Out:
# {1: 'TCS', 2: 'Google', 3: 'TATA', 1101: 'pune', 102: 'mumbai'}

# %% [markdown]
# 15. Make a dictionary and get the value of a key using get().

# %%
sd={1: 'TCS', 2: 'Google', 3: 'TATA', 1101: 'pune', 102: 'mumbai'}
sd.get(3)
# Out:
# 'TATA'

# %% [markdown]
# 16. Create a dictionary and print its type using type().

# %%
dict={}
type(dict)
# Out:
# dict

# %% [markdown]
# 17. Create a dictionary and replace one value with a new one.

# %%
abc={"name":"xyz","city":"pune","gender":"M","status":"Active"}
abc.update({"city":"Kolhapur"})
abc
# Out:
# {'name': 'xyz', 'city': 'Kolhapur', 'gender': 'M', 'status': 'Active'}

# %% [markdown]
# 18. Create a dictionary and clear all items using clear().

# %%
abc={"name":"xyz","city":"pune","gender":"M","status":"Active"}
abc.clear()
abc
# Out:
# {}

# %% [markdown]
# 19. Create a dictionary with numbers as keys and names as values. Print the dictionary.

# %%
dict={1:"abc",2:"xyz",3:"pqr",4:"klm"}
dict
# Out:
# {1: 'abc', 2: 'xyz', 3: 'pqr', 4: 'klm'}

# %% [markdown]
# 20. Create a dictionary and copy it into a new dictionary using copy().

# %%
abc={"name":"xyz","city":"pune","gender":"M","status":"Active"}
xyz=abc.copy()
xyz
# Out:
# {'name': 'xyz', 'city': 'pune', 'gender': 'M', 'status': 'Active'}
